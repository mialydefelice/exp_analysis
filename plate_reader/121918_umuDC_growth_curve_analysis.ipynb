# %% [markdown]
# 121918 - umuDC Growth Curve Analysis

# %%
#import packages
import datetime
import itertools
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import re
import csv
import seaborn as sns
# %matplotlib inline

# %%
from functions.data_handling import *
from functions.plots import *

# %%
'''
Note: Merging biological replicates will merge all associated technical replicates as well.
'''

base_file_path = '/Users/mialydefelice/Dropbox/Mialy/Experiments/TranscriptionUnitStructure'
additional_path_info = '2018'
file_name_base = '121918_umuD_C_Growth'
merge_biological_replicates = True
merge_tech_replicates = False
wells_to_exclude = []

# %%
df_data, df_merged, time = parse_data_file(file_name_base, base_file_path, wells_to_exclude, 
                                          merge_biological_replicates, merge_tech_replicates)

# %%
fig_save_path = create_fig_save_folder(base_file_path, file_name_base)
quick_plot_all_wells(df_data, fig_save_path, 1.2)

# %%
#make figures divivded by organism

BW_LB = [['B6', 'C6', 'D6', 'E6', 'F6', 'G6']]
del_D_LB = [['B8', 'C8', 'D8', 'E8', 'F8', 'G8']]
del_C_LB = [['B10', 'C10', 'D10', 'E10', 'F10', 'G10']]

conditions = [BW_LB, del_D_LB, del_C_LB]
condition_names = ['BW_LB','del_umuD_LB', 'del_umuC_LB']

# %%
make_individual_plots(time, conditions, condition_names, df_merged, fig_save_path, 1, [0, 1440], 'UV_Stimulation_')

# %%
#divided by organism M9 media
BW_M9 = [['B2', 'C2', 'D2', 'E2', 'F2', 'G2']]
delC_M9 = [['B4', 'C4', 'D4', 'E4', 'F4', 'G4']]

conditions = [BW_M9, delC_M9]
condition_names = ['BW_M9', 'delC_M9']
make_individual_plots(time, conditions, condition_names, df_merged, fig_save_path, 0.5, [0, 1440], 'UV_Stimulation_')

# %%
#make figures divided by stim time
no_stim_M9 = [['B2', 'B4']]
one_min_M9 = [['C2', 'C4']]
two_min_M9 = [['D2', 'D4']]
three_min_M9 = [['E2', 'E4']]
four_min_M9 = [['F2', 'F4']]
five_min_M9 = [['G2', 'G4']]

conditions = [no_stim_M9, one_min_M9, two_min_M9, three_min_M9, four_min_M9, five_min_M9]
condition_names = ['no_stim_M9', 'one_min_M9', 'two_min_M9',
                   'three_min_M9', 'four_min_M9', 'five_min_M9']
make_individual_plots(time, conditions, condition_names, df_merged, fig_save_path, 1, [0, 1440], 'UV_Stimulation_')

# %%
#make figures divided by stim time
no_stim = [['B6', 'B8', 'B10']]
five_min = [['C6', 'C8', 'C10']]
five_min_1_min = [['D6', 'D8', 'D10']]
five_min_5_min = [['E6', 'E8', 'E10']]
ten_min = [['F6', 'F8', 'F10']]
twenty_min = [['G6', 'G8', 'G10']]

conditions = [no_stim, five_min, five_min_1_min, five_min_5_min, ten_min, twenty_min]
condition_names = ['no_stim_LB', 'five_min_LB', 'five_min_1_min_LB',
                   'five_min_5_min_LB', 'ten_min_LB', 'twenty_min_LB']
make_individual_plots(time, conditions, condition_names, df_merged, fig_save_path, 1, [0, 1440], 'UV_Stimulation_')
