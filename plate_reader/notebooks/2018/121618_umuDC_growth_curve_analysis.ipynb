# %% [markdown]
# 121618 - umuDC Growth Curve Analysis

# %%
#import packages

import datetime
import itertools
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import re
import csv
import seaborn as sns
# %matplotlib inline

# %%
from functions.data_handling import *
from functions.plots import *

# %%
base_file_path = '/Users/mialydefelice/Dropbox/Mialy/Experiments/TranscriptionUnitStructure'
file_name = '121618_UmuD_C_Growth.txt'

# %%
df = parse_data_file(file_name, base_file_path)
df
# Out:
#                                                     600
# time  (0:00:00, 0:10:02, 0:20:03, 0:30:03, 0:40:04, ...
# temp  (37.0, 37.0, 37.0, 37.0, 37.0, 37.0, 37.0, 37....
# A1    (0.085, 0.084, 0.084, 0.084, 0.084, 0.084, 0.0...
# A2    (0.083, 0.082, 0.082, 0.082, 0.082, 0.082, 0.0...
# A3    (0.196, 0.187, 0.119, 0.098, 0.090, 0.083, 0.0...
# A4    (0.083, 0.083, 0.085, 0.083, 0.083, 0.083, 0.0...
# A5    (0.084, 0.083, 0.083, 0.083, 0.083, 0.083, 0.0...
# A6    (0.085, 0.085, 0.085, 0.085, 0.085, 0.085, 0.0...
# A7    (0.087, 0.087, 0.087, 0.087, 0.087, 0.086, 0.0...
# A8    (0.085, 0.084, 0.084, 0.084, 0.084, 0.091, 0.0...
# A9    (0.089, 0.089, 0.089, 0.089, 0.089, 0.089, 0.0...
# A10   (0.083, 0.083, 0.083, 0.082, 0.082, 0.082, 0.0...
# A11   (0.089, 0.089, 0.089, 0.089, 0.089, 0.089, 0.0...
# A12   (0.084, 0.084, 0.084, 0.083, 0.083, 0.083, 0.0...
# B1    (0.084, 0.083, 0.083, 0.082, 0.083, 0.083, 0.0...
# B2    (0.082, 0.085, 0.084, 0.081, 0.081, 0.081, 0.0...
# B3    (0.096, 0.096, 0.099, 0.102, 0.108, 0.115, 0.1...
# B4    (0.091, 0.092, 0.095, 0.098, 0.104, 0.112, 0.1...
# B5    (0.092, 0.092, 0.094, 0.098, 0.103, 0.111, 0.1...
# B6    (0.090, 0.090, 0.091, 0.094, 0.097, 0.101, 0.1...
# B7    (0.090, 0.090, 0.091, 0.093, 0.096, 0.101, 0.1...
# B8    (0.089, 0.089, 0.090, 0.091, 0.094, 0.098, 0.1...
# B9    (0.089, 0.089, 0.090, 0.093, 0.096, 0.100, 0.1...
# B10   (0.090, 0.090, 0.091, 0.094, 0.097, 0.101, 0.1...
# B11   (0.091, 0.091, 0.092, 0.097, 0.098, 0.102, 0.1...
# B12   (0.084, 0.083, 0.083, 0.083, 0.083, 0.083, 0.0...
# C1    (0.084, 0.082, 0.082, 0.082, 0.082, 0.082, 0.0...
# C2    (0.083, 0.082, 0.082, 0.082, 0.082, 0.082, 0.0...
# C3    (0.095, 0.095, 0.097, 0.100, 0.104, 0.111, 0.1...
# C4    (0.094, 0.093, 0.095, 0.098, 0.103, 0.109, 0.1...
# ...                                                 ...
# F7    (0.091, 0.090, 0.091, 0.092, 0.094, 0.097, 0.1...
# F8    (0.089, 0.089, 0.090, 0.091, 0.092, 0.094, 0.0...
# F9    (0.090, 0.090, 0.091, 0.092, 0.093, 0.096, 0.0...
# F10   (0.095, 0.094, 0.095, 0.096, 0.097, 0.099, 0.1...
# F11   (0.089, 0.089, 0.090, 0.092, 0.093, 0.096, 0.0...
# F12   (0.084, 0.084, 0.084, 0.084, 0.084, 0.085, 0.0...
# G1    (0.083, 0.083, 0.083, 0.083, 0.083, 0.083, 0.0...
# G2    (0.081, 0.081, 0.081, 0.081, 0.081, 0.081, 0.0...
# G3    (0.093, 0.093, 0.095, 0.099, 0.103, 0.111, 0.1...
# G4    (0.099, 0.099, 0.100, 0.103, 0.107, 0.112, 0.1...
# G5    (0.092, 0.092, 0.095, 0.098, 0.102, 0.108, 0.1...
# G6    (0.092, 0.091, 0.093, 0.094, 0.096, 0.099, 0.1...
# G7    (0.092, 0.092, 0.093, 0.095, 0.097, 0.100, 0.1...
# G8    (0.088, 0.088, 0.089, 0.090, 0.092, 0.094, 0.0...
# G9    (0.090, 0.090, 0.091, 0.092, 0.094, 0.097, 0.1...
# G10   (0.096, 0.096, 0.096, 0.098, 0.100, 0.102, 0.1...
# G11   (0.091, 0.091, 0.092, 0.093, 0.095, 0.097, 0.1...
# G12   (0.084, 0.084, 0.084, 0.084, 0.084, 0.085, 0.0...
# H1    (0.083, 0.082, 0.082, 0.082, 0.082, 0.082, 0.0...
# H2    (0.083, 0.082, 0.082, 0.082, 0.081, 0.082, 0.0...
# H3    (0.083, 0.082, 0.082, 0.082, 0.082, 0.082, 0.0...
# H4    (0.083, 0.083, 0.084, 0.084, 0.084, 0.084, 0.0...
# H5    (0.083, 0.083, 0.083, 0.083, 0.083, 0.083, 0.0...
# H6    (0.085, 0.085, 0.084, 0.084, 0.084, 0.084, 0.0...
# H7    (0.083, 0.083, 0.083, 0.083, 0.083, 0.083, 0.0...
# H8    (0.088, 0.088, 0.088, 0.088, 0.088, 0.088, 0.0...
# H9    (0.092, 0.094, 0.094, 0.093, 0.093, 0.093, 0.0...
# H10   (0.089, 0.091, 0.091, 0.092, 0.092, 0.092, 0.0...
# H11   (0.082, 0.082, 0.082, 0.082, 0.082, 0.082, 0.0...
# H12   (0.088, 0.088, 0.087, 0.087, 0.087, 0.088, 0.0...
#
# [98 rows x 1 columns]

# %%
fig_save_path = create_fig_save_folder(base_file_path, file_name)
quick_plot_all_wells(df, fig_save_path, 1)
