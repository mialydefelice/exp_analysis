# %%
#import packages
import datetime
import itertools
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import re
import csv
import seaborn as sns
# %matplotlib inline

# %%
from functions.data_handling import *
from functions.plots import *

# %%
'''
Note: Merging biological replicates will merge all associated technical replicates as well.
'''

base_file_path = '/Users/mialydefelice/Dropbox/Mialy/Experiments/TranscriptionUnitStructure'
additional_path_info = '2019'
file_name_base = '041019_mdtNOP_sulfadiazine'
merge_biological_replicates = False
merge_tech_replicates = False
wells_to_exclude = []

# %%
df_data, df_merged, time = parse_data_file(file_name_base, base_file_path, wells_to_exclude, 
                                          merge_biological_replicates, merge_tech_replicates)

# %%
fig_save_path = create_fig_save_folder(base_file_path, file_name_base)
quick_plot_all_wells(df_data, fig_save_path, 1.2)

# %%
#make figures divivded by organism

BW_media = [['B2', 'C2', 'D2', 'E2']]
BW_media_dmso = [['B3', 'C3', 'D3', 'E3']]
del_mdtN = [['B4', 'C4', 'D4', 'E4', 'F4', 'G4']]
del_mdtO = [['B5', 'C5', 'D5', 'E5', 'F5', 'G5']]
del_mdtP = [['B6', 'C6', 'D6', 'E6', 'F6', 'G6']]

conditions = [BW_media, BW_media_dmso, del_mdtN, del_mdtO, del_mdtP]
condition_names = ['BW_media','BW_media_dmso', 'del_mdtN', 'del_mdtO', 'del_mdtP']

# %%
make_individual_plots(time, conditions, condition_names, df_merged, fig_save_path, 1, [0, 1440], 'Sulfa_drug_stim')

# %%
sulfa_800 = [['B4', 'B5', 'B6', 'B7']]
sulfa_500 = [['C4', 'C5', 'C6', 'C7']]
sulfa_400 = [['D4', 'D5', 'D6', 'D7']]
sulfa_300 = [['E4', 'E5', 'E6', 'E7']]
sulfa_250 = [['F4', 'F5', 'F6', 'F7']]
sulfa_200 = [['G4', 'G5', 'G6', 'G7']]
BW_media = [['B2', 'C2', 'D2', 'E2']]
BW_media_dmso = [['B3', 'C3', 'D3', 'E3']]

conditions = [sulfa_800, sulfa_500, sulfa_400, sulfa_300, sulfa_250, sulfa_200, BW_media, BW_media_dmso]
condition_names = ['sulfa_800','sulfa_500', 'sulfa_400', 'sulfa_300', 'sulfa_250', 'sulfa_200', 'BW_media', 'BW_media_dmso']

# %%
make_individual_plots(time, conditions, condition_names, df_merged, fig_save_path, 1, [0, 1440], 'Sulfa_drug_by_conc')
