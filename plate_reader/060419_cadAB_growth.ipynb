# %%
#import packages
import datetime
import itertools
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import re
import csv
import seaborn as sns
# %matplotlib inline

# %%
from functions.data_handling import *
from functions.plots import *

# %%
'''
Note: Merging biological replicates will merge all associated technical replicates as well.
'''

base_file_path = '/Users/mialydefelice/Dropbox/Papers/NSF_Grant_2019/Figures/Figure4'
additional_path_info = '2019'
file_name_base = '060419_cadAB'
merge_biological_replicates = True
merge_tech_replicates = True
wells_to_exclude = []

# %%
df_data, df_merged, time = parse_data_file(file_name_base, base_file_path, wells_to_exclude, 
                                          merge_biological_replicates, merge_tech_replicates)
# Out:
# ([10, 43], [])
# ['30', 'Read']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-6742dcaad0cc> in <module>()
#       1 df_data, df_merged, time = parse_data_file(file_name_base, base_file_path, wells_to_exclude,
# ----> 2                                           merge_biological_replicates, merge_tech_replicates)
#
# /Users/mialydefelice/Documents/code_repositories/exp_analysis/plate_reader/functions/data_handling.py in parse_data_file(filename, base_file_path, wells_to_exclude, merge_bio_rep, merge_tech_rep)
#     335     data_path = find_data_path(filename, base_file_path)
#     336     imported_data = import_data(data_path[0])
# --> 337     data_all_waves, waves_used = get_list_of_data(imported_data)
#     338     df = create_df_all_wavelengths(data_all_waves, waves_used)
#     339     time = get_time_axis(df, waves_used[0])
#
# /Users/mialydefelice/Documents/code_repositories/exp_analysis/plate_reader/functions/data_handling.py in get_list_of_data(data)
#     145     data_all_wavelengths = []
#     146     for i in range(0, len(data_bounds[0])):
# --> 147         data_all_wavelengths.append(data[data_bounds[0][i]: data_bounds[1][i]])
#     148     return data_all_wavelengths, wavelengths_used
#     149
#
# IndexError: list index out of range

# %%
fig_save_path = create_fig_save_folder(base_file_path, file_name_base)
quick_plot_all_wells(df_data, fig_save_path, 0.6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f3032bfe3b9d> in <module>()
#       1 fig_save_path = create_fig_save_folder(base_file_path, file_name_base)
# ----> 2 quick_plot_all_wells(df_data, fig_save_path, 0.6)
#
# NameError: name 'df_data' is not defined

# %%
#make figures divivded by organism

MG1655 = [['C2']]
del_pabC = [['C3']]
del_pabC_no_kan = [['C4']]

conditions = [MG1655, del_pabC, del_pabC_no_kan]
condition_names = ['MG1655','del_pabC', 'del_pabC_no_kan']

# %%
df_merged
# Out:
#                                                        600  \
# well_id
# C2       [[0.085, 0.084, 0.083, 0.083, 0.084, 0.084, 0....
# C3       [[0.087, 0.087, 0.087, 0.088, 0.088, 0.089, 0....
# C4       [[0.084, 0.084, 0.084, 0.085, 0.085, 0.086, 0....
# G2       [[0.077, 0.077, 0.077, 0.077, 0.077, 0.077, 0....
#
#                                cell  \
# well_id
# C2                MG1655_Glucose_M9
# C3              del_pabC_Glucose_M9
# C4       del_pabC_no_kan_Glucose_M9
# G2                 Media_Glucose_M9
#
#                                               600_averaged  \
# well_id
# C2       [0.08524999999999999, 0.0835, 0.083, 0.08275, ...
# C3       [0.08625, 0.08625, 0.0865, 0.08725, 0.0875, 0....
# C4       [0.08524999999999999, 0.08499999999999999, 0.0...
# G2       [0.07633333333333332, 0.07633333333333332, 0.0...
#
#                                                    600_std
# well_id
# C2       [0.0004999999999999935, 0.0005773502691896263,...
# C3       [0.0005000000000000004, 0.0005000000000000004,...
# C4       [0.0012583057392117863, 0.0014142135623730898,...
# G2       [0.0005773502691896263, 0.0005773502691896263,...

# %%
make_individual_plots(time, conditions, condition_names, df_merged, fig_save_path, 1, [0, 1440], 'pabC_growth_Curve')

# %%
make_individual_plots_subplot(time, conditions, condition_names, df_merged, fig_save_path, 1, [0, 1440], 'pabC_growth_Curve_subplot')
